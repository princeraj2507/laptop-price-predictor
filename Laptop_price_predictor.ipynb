# %% [markdown]
# # <h1><center>Laptop Price Predictor</center></h1>
# ## Problem Statement
#     Predict the Price of laptop on the basis
#     a dataset for 1300 laptop models.
# ## Flow of Model
#     1.Pandas Profiling report
#     2.Exploratory Data Analysis
#     3.Feature Engineering
#     4.Model Selection
#     5.Exporting the Model
#     6.Observation
#
# ## Performance Metric
#    1.R2 Score
#    2. Mean Absolute score

# %%
import numpy as np 
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('laptop_check.csv')

# %%
df
# Out:
#       Unnamed: 0 Company            TypeName  Inches  \
# 0              0   Apple           Ultrabook    13.3
# 1              1   Apple           Ultrabook    13.3
# 2              2      HP            Notebook    15.6
# 3              3   Apple           Ultrabook    15.4
# 4              4   Apple           Ultrabook    13.3
# ...          ...     ...                 ...     ...
# 1298        1298  Lenovo  2 in 1 Convertible    14.0
# 1299        1299  Lenovo  2 in 1 Convertible    13.3
# 1300        1300  Lenovo            Notebook    14.0
# 1301        1301      HP            Notebook    15.6
# 1302        1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # 1. Pandas Profiling Report

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output_check.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df
# Out:
#      Company            TypeName  Inches  \
# 0      Apple           Ultrabook    13.3
# 1      Apple           Ultrabook    13.3
# 2         HP            Notebook    15.6
# 3      Apple           Ultrabook    15.4
# 4      Apple           Ultrabook    13.3
# ...      ...                 ...     ...
# 1298  Lenovo  2 in 1 Convertible    14.0
# 1299  Lenovo  2 in 1 Convertible    13.3
# 1300  Lenovo            Notebook    14.0
# 1301      HP            Notebook    15.6
# 1302    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# ...

# %%
df['Ram']=df['Ram'].str.replace('GB','')

# %%
df['Weight']=df['Weight'].str.replace('kg','')

# %%
df.head(5)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
df['Ram']=df['Ram'].astype('int32')
df['Weight']=df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   int32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(1), float64(2), int32(1), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# # 2.Exploratory Data Analysis

# %%
import seaborn as sns

# %% [markdown]
# ### Dealing with Price feature

# %%
sns.displot(df['Price'])
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Histogram of Prices')

# Display the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Dealing with Company feature

# %%
df['Company'].value_counts().plot(kind='bar')
plt.xlabel('Company')
plt.ylabel('Frequency')
plt.title('Histogram of Prices')
# Out:
# Text(0.5, 1.0, 'Histogram of Prices')

# %%
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
#  ### Dealing with TypeName feature

# %%
df['TypeName'].value_counts().plot(kind='bar')
plt.xlabel('TypeName')
plt.ylabel('Frequency')
plt.title('Histogram of Prices')
# Out:
# Text(0.5, 1.0, 'Histogram of Prices')

# %%
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Dealing with Inches feature

# %%
df['Inches'].value_counts().plot(kind='bar')
plt.xlabel('Inches')
plt.ylabel('Frequency')
plt.title('Histogram of Prices')
# Out:
# Text(0.5, 1.0, 'Histogram of Prices')

# %%
sns.barplot(x=df['Inches'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Dealing with the screenresolution column

# %%
target_word = 'Touchscreen'
df['Touchscreen'] = df['ScreenResolution'].str.contains(target_word, case=1)
df['Touchscreen']=df['Touchscreen'].astype('int32')

df.head(20)
# Out:
#    Company   TypeName  Inches                           ScreenResolution  \
# 0    Apple  Ultrabook    13.3         IPS Panel Retina Display 2560x1600
# 1    Apple  Ultrabook    13.3                                   1440x900
# 2       HP   Notebook    15.6                          Full HD 1920x1080
# 3    Apple  Ultrabook    15.4         IPS Panel Retina Display 2880x1800
# 4    Apple  Ultrabook    13.3         IPS Panel Retina Display 2560x1600
# 5     Acer   Notebook    15.6                                   1366x768
# 6    Apple  Ultrabook    15.4         IPS Panel Retina Display 2880x1800
# 7    Apple  Ultrabook    13.3                                   1440x900
# 8     Asus  Ultrabook    14.0                          Full HD 1920x1080
# 9     Acer  Ultrabook    14.0                IPS Panel Full HD 1920x1080
# 10      HP   Notebook    15.6                                   1366x768
# 11      HP   Notebook    15.6                          Full HD 1920x1080
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
plt.xlabel('Touchscreen')
plt.ylabel('Frequency')
plt.title('Histogram of Touchscreen')
# Out:
# Text(0.5, 1.0, 'Histogram of Touchscreen')

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# print("Corelation value is",df.corr()['Price']['Touchscreen'])

# %%
target_word = 'IPS'

# Check if the target word exists in the 'text_column' using str.contains()
df['Ips'] = df['ScreenResolution'].str.contains(target_word, case=1)

df['Ips']=df['Ips'].astype('int32')

df.head(5)
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu  Ram               Memory  \
# 0        Intel Core i5 2.3GHz    8            128GB SSD
# 1        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3        Intel Core i7 2.7GHz   16            512GB SSD
# 4        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# ...

# %%
df['Ips'].value_counts().plot(kind='bar')
plt.xlabel('Ips')
plt.ylabel('Frequency')
plt.title('Histogram of Ips')
# Out:
# Text(0.5, 1.0, 'Histogram of Ips')

# %%
sns.barplot(x=df['Ips'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()
# print("Corelation value is",df.corr()['Price']['Ips'])

# %%
new = df['ScreenResolution'].str.split('x',n=1,expand=True)
new
# Out:
#                                           0     1
# 0             IPS Panel Retina Display 2560  1600
# 1                                      1440   900
# 2                              Full HD 1920  1080
# 3             IPS Panel Retina Display 2880  1800
# 4             IPS Panel Retina Display 2560  1600
# ...                                     ...   ...
# 1298   IPS Panel Full HD / Touchscreen 1920  1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200  1800
# 1300                                   1366   768
# 1301                                   1366   768
# 1302                                   1366   768
#
# [1303 rows x 2 columns]

# %%
df['X_res'] = new[0]
df['Y_res'] = new[1]

# %%
df.sample(5)
# Out:
#     Company   TypeName  Inches                     ScreenResolution  \
# 84     Acer   Notebook    15.6                             1366x768
# 735  Lenovo   Notebook    15.6                    Full HD 1920x1080
# 328      HP  Ultrabook    12.5                    Full HD 1920x1080
# 167    Dell     Gaming    15.6                    Full HD 1920x1080
# 830   Razer     Gaming    17.3  4K Ultra HD / Touchscreen 3840x2160
#
#                              Cpu  Ram                Memory  \
# 84       AMD A9-Series 9420 3GHz    4               1TB HDD
# 735   Intel Core i7 7500U 2.7GHz    4               1TB HDD
# 328   Intel Core i7 7500U 2.7GHz    8             256GB SSD
# 167  Intel Core i7 7700HQ 2.8GHz    8  128GB SSD +  1TB HDD
# 830  Intel Core i7 7820HK 2.9GHz   32             512GB SSD
#
#                          Gpu       OpSys  Weight        Price  Touchscreen  \
# 84             AMD Radeon R5  Windows 10    2.10   21045.6000            0
# ...

# %%
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply(lambda x:x[0])

# %%
df.sample(5)
# Out:
#      Company            TypeName  Inches                 ScreenResolution  \
# 1073      HP            Notebook    13.3                Full HD 1920x1080
# 899     Dell            Notebook    15.6                Full HD 1920x1080
# 317   Lenovo            Notebook    13.3                         1366x768
# 23      Dell  2 in 1 Convertible    13.3  Full HD / Touchscreen 1920x1080
# 132     Acer           Ultrabook    14.0      IPS Panel Full HD 1920x1080
#
#                                        Cpu  Ram              Memory  \
# 1073            Intel Core i7 7500U 2.7GHz    8           256GB SSD
# 899             Intel Core i5 7300U 2.6GHz    8           500GB HDD
# 317   Intel Celeron Dual Core 3855U 1.6GHz    4  16GB Flash Storage
# 23              Intel Core i5 8250U 1.6GHz    8           256GB SSD
# 132             Intel Core i7 8550U 1.8GHz    8           256GB SSD
#
#                          Gpu       OpSys  Weight      Price  Touchscreen  Ips  \
# ...

# %%
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %%
df['ppi'] = (((df['X_res']**2) + (df['Y_res']**2))**0.5/df['Inches']).astype('float')

# %%
df.corr()['Price']
# Out:
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.drop(columns=['ScreenResolution'],inplace=True)

# %%
df.drop(columns=['Inches','X_res','Y_res'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu  Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz    8            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz    8            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz   16            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz    8            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  Ips  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983005
# 1  127.677940
# ...

# %% [markdown]
# ### Dealing with CPU feature

# %%
df['Cpu'].value_counts()
# Out:
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core M M3-6Y30 0.9GHz        1
# AMD A9-Series 9420 2.9GHz          1
# Intel Core i3 6006U 2.2GHz         1
# AMD A6-Series 7310 2GHz            1
# Intel Xeon E3-1535M v6 3.1GHz      1
# Name: Cpu, Length: 118, dtype: int64

# %%
df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.sample(5)
# Out:
#      Company  TypeName                                   Cpu  Ram  \
# 342       HP  Notebook            Intel Core i3 7100U 2.4GHz    8
# 856     Asus  Notebook  Intel Pentium Quad Core N4200 1.1GHz    4
# 819     Dell  Notebook            Intel Core i5 6200U 2.3GHz    4
# 1267    Dell  Notebook            Intel Core i7 7500U 2.7GHz    8
# 937      MSI    Gaming           Intel Core i7 7700HQ 2.8GHz    8
#
#                     Memory                      Gpu       OpSys  Weight  \
# 342                1TB HDD    Nvidia GeForce 930MX   Windows 10    2.10
# 856                1TB HDD    Intel HD Graphics 505  Windows 10    2.00
# 819              500GB HDD    Intel HD Graphics 520  Windows 10    1.76
# 1267               1TB HDD       AMD Radeon R5 M430       Linux    2.30
# 937   128GB SSD +  1TB HDD  Nvidia GeForce GTX 1050  Windows 10    2.20
#
#            Price  Touchscreen  Ips         ppi            Cpu Name
# 342   38148.4800            0    1  141.211998       Intel Core i3
# ...

# %%
#  Assigning classes to Cpu Name feature
def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.sample(5)
# Out:
#      Company     TypeName                                   Cpu  Ram  \
# 1093    Dell    Ultrabook            Intel Core i5 8250U 1.6GHz    4
# 147     Asus     Notebook  Intel Celeron Dual Core N3350 1.1GHz    4
# 910     Dell     Notebook           Intel Core i5 7440HQ 2.8GHz    8
# 445     Dell     Notebook           Intel Core i5 7440HQ 2.8GHz    8
# 410   Lenovo  Workstation           Intel Core i7 7700HQ 2.8GHz    8
#
#          Memory                    Gpu       OpSys  Weight       Price  \
# 1093  256GB SSD         AMD Radeon 530  Windows 10    1.40   43601.688
# 147     1TB HDD  Intel HD Graphics 500  Windows 10    2.00   18328.320
# 910   256GB SSD  Intel HD Graphics 620  Windows 10    1.60   64202.400
# 445   256GB SSD   Nvidia GeForce 930MX  Windows 10    1.64   62817.120
# 410   512GB SSD    Nvidia Quadro M1200  Windows 10    2.67  102564.000
#
#       Touchscreen  Ips         ppi            Cpu Name              Cpu brand
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
plt.xlabel('Cpu brand')
plt.ylabel('Frequency')
plt.title('Histogram of Cpu brand')
# Out:
# Text(0.5, 1.0, 'Histogram of Cpu brand')

# %%
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Cpu','Cpu Name'],inplace=True)

# %%
df.sample(5)
# Out:
#     Company     TypeName  Ram                Memory                       Gpu  \
# 362  Lenovo     Notebook    6  128GB SSD +  1TB HDD  Nvidia GeForce GTX 940MX
# 618     MSI       Gaming   16  256GB SSD +  1TB HDD   Nvidia GeForce GTX 1070
# 823     MSI       Gaming    8             256GB SSD   Nvidia GeForce GTX 1050
# 599    Dell  Workstation    8             256GB SSD        Nvidia Quadro M620
# 38       HP     Notebook    4               1TB HDD     Intel HD Graphics 620
#
#           OpSys  Weight        Price  Touchscreen  Ips         ppi  \
# 362  Windows 10    2.80   38308.3200            0    0  106.113062
# 618  Windows 10    2.94  120831.5808            0    0  141.211998
# 823  Windows 10    2.40   63882.7200            0    0  141.211998
# 599  Windows 10    2.06   93932.6400            1    0  141.211998
# 38   Windows 10    1.86   26037.4032            0    0  100.454670
#
#          Cpu brand
# 362  Intel Core i5
# 618  Intel Core i7
# 823  Intel Core i5
# ...

# %% [markdown]
# ### Dealing with Ram feature

# %%
df['Ram'].value_counts().plot(kind='bar')
plt.xlabel('Ram')
plt.ylabel('Frequency')
plt.title('Histogram of  Ram')
# Out:
# Text(0.5, 1.0, 'Histogram of  Ram')

# %%
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.corr()['Price']
# Out:
# Ram            0.743007
# Weight         0.210370
# Price          1.000000
# Touchscreen    0.191226
# Ips            0.252208
# ppi            0.473487
# Name: Price, dtype: float64

# %%
df.sample(5)
# Out:
#     Company  TypeName  Ram                Memory                         Gpu  \
# 557  Lenovo  Notebook    6  128GB SSD +  1TB HDD        Nvidia GeForce 940MX
# 134      HP  Notebook    8               1TB HDD       Intel HD Graphics 620
# 298  Lenovo  Notebook    6               1TB HDD           AMD Radeon R5 430
# 391    Asus    Gaming   16  256GB SSD +  1TB HDD  Nvidia GeForce GTX 1050 Ti
# 969  Lenovo  Notebook    6             256GB SSD        Nvidia GeForce 920MX
#
#           OpSys  Weight     Price  Touchscreen  Ips         ppi      Cpu brand
# 557  Windows 10    2.80  50562.72            0    0  106.113062  Intel Core i7
# 134  Windows 10    2.05  31861.44            0    0  100.454670  Intel Core i7
# 298  Windows 10    2.40  26586.72            0    0  141.211998  AMD Processor
# 391  Windows 10    3.00  84768.48            0    0  127.335675  Intel Core i7
# 969  Windows 10    2.40  37029.60            0    0  141.211998  Intel Core i5

# %% [markdown]
# ### Dealing with Memory column

# %%
df['Memory'].value_counts()
# Out:
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 512GB SSD +  1TB HDD              14
# 1TB SSD                           14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 512GB SSD +  2TB HDD               3
# 16GB SSD                           3
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# 256GB SSD +  500GB HDD             2
# 128GB SSD +  2TB HDD               2
# ...

# %%
df['Memory'] = df['Memory'].astype(str).replace('\.0', '', regex=True)
df["Memory"] = df["Memory"].str.replace('GB', '')
df["Memory"] = df["Memory"].str.replace('TB', '000')
new = df["Memory"].str.split("+", n = 1, expand = True)

df["first"]= new[0]
df["first"]=df["first"].str.strip()

df["second"]= new[1]

df["Layer1HDD"] = df["first"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer1SSD"] = df["first"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer1Hybrid"] = df["first"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer1Flash_Storage"] = df["first"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['first'] = df['first'].str.replace(r'\D', '')

df["second"].fillna("0", inplace = True)

df["Layer2HDD"] = df["second"].apply(lambda x: 1 if "HDD" in x else 0)
df["Layer2SSD"] = df["second"].apply(lambda x: 1 if "SSD" in x else 0)
df["Layer2Hybrid"] = df["second"].apply(lambda x: 1 if "Hybrid" in x else 0)
df["Layer2Flash_Storage"] = df["second"].apply(lambda x: 1 if "Flash Storage" in x else 0)

df['second'] = df['second'].str.replace(r'\D', '')

df["first"] = df["first"].astype(int)
df["second"] = df["second"].astype(int)

df["HDD"]=(df["first"]*df["Layer1HDD"]+df["second"]*df["Layer2HDD"])
df["SSD"]=(df["first"]*df["Layer1SSD"]+df["second"]*df["Layer2SSD"])
df["Hybrid"]=(df["first"]*df["Layer1Hybrid"]+df["second"]*df["Layer2Hybrid"])
df["Flash_Storage"]=(df["first"]*df["Layer1Flash_Storage"]+df["second"]*df["Layer2Flash_Storage"])

df.drop(columns=['first', 'second', 'Layer1HDD', 'Layer1SSD', 'Layer1Hybrid',
       'Layer1Flash_Storage', 'Layer2HDD', 'Layer2SSD', 'Layer2Hybrid',
       'Layer2Flash_Storage'],inplace=True)

# %%
df.sample(5)
# Out:
#       Company  TypeName  Ram   Memory                    Gpu       OpSys  \
# 1089     Acer  Notebook    4  500 HDD          AMD Radeon R5  Windows 10
# 923   Toshiba  Notebook   16  256 SSD    Nvidia GeForce 930M  Windows 10
# 394      Dell  Notebook    8  256 SSD     AMD Radeon R7 M445       Linux
# 904    Lenovo  Notebook    8  512 SSD  Intel HD Graphics 620  Windows 10
# 985      Dell  Notebook    4  500 HDD     AMD Radeon R5 M430  Windows 10
#
#       Weight        Price  Touchscreen  Ips         ppi      Cpu brand  HDD  \
# 1089    2.40   20619.3600            0    0  100.454670  AMD Processor  500
# 923     2.40  105228.0000            0    1  141.211998  Intel Core i7    0
# 394     2.33   41498.1936            0    0  141.211998  Intel Core i7    0
# 904     1.95  104588.1072            0    1  141.211998  Intel Core i5    0
# 985     2.25   31914.7200            0    0  100.454670  Intel Core i5  500
#
#       SSD  Hybrid  Flash_Storage
# 1089    0       0              0
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.sample(5)
# Out:
#     Company            TypeName  Ram                     Gpu       OpSys  \
# 43     Acer            Notebook    4  Intel UHD Graphics 620  Windows 10
# 14    Apple           Ultrabook    8   Intel HD Graphics 615       macOS
# 303  Lenovo            Notebook    8    Nvidia GeForce 940MX       No OS
# 867  Lenovo  2 in 1 Convertible    8   Intel HD Graphics 620  Windows 10
# 437  Google           Ultrabook   16   Intel HD Graphics 615   Chrome OS
#
#      Weight       Price  Touchscreen  Ips         ppi              Cpu brand  \
# 43     2.20   36336.960            0    1  141.211998          Intel Core i5
# 14     0.92   67260.672            0    1  226.415547  Other Intel Processor
# 303    2.20   29250.720            0    0  100.454670          Intel Core i5
# 867    1.37  103896.000            1    1  165.632118          Intel Core i7
# 437    1.10  117162.720            1    0  234.507400          Intel Core i7
#
#       HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
df.corr()['Price']
# Out:
# Ram              0.743007
# Weight           0.210370
# Price            1.000000
# Touchscreen      0.191226
# Ips              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head(5)
# Out:
#   Company   TypeName  Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook    8  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook    8        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook    8         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook   16            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook    8  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  Ips         ppi      Cpu brand  HDD  SSD
# 0   71378.6832            0    1  226.983005  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.211998  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534624  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983005  Intel Core i5    0  256

# %% [markdown]
# ### Dealing with Gpu feature

# %%
df['Gpu'].value_counts()
# Out:
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R5 520            1
# AMD Radeon R7                1
# Intel HD Graphics 540        1
# AMD Radeon 540               1
# ARM Mali T860 MP4            1
# Name: Gpu, Length: 110, dtype: int64

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df
# Out:
#      Company            TypeName  Ram                           Gpu  \
# 0      Apple           Ultrabook    8  Intel Iris Plus Graphics 640
# 1      Apple           Ultrabook    8        Intel HD Graphics 6000
# 2         HP            Notebook    8         Intel HD Graphics 620
# 3      Apple           Ultrabook   16            AMD Radeon Pro 455
# 4      Apple           Ultrabook    8  Intel Iris Plus Graphics 650
# ...      ...                 ...  ...                           ...
# 1298  Lenovo  2 in 1 Convertible    4         Intel HD Graphics 520
# 1299  Lenovo  2 in 1 Convertible   16         Intel HD Graphics 520
# 1300  Lenovo            Notebook    2             Intel HD Graphics
# 1301      HP            Notebook    6            AMD Radeon R5 M330
# 1302    Asus            Notebook    4             Intel HD Graphics
#
#            OpSys  Weight        Price  Touchscreen  Ips         ppi  \
# 0          macOS    1.37   71378.6832            0    1  226.983005
# ...

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: Gpu brand, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Intel     722
# Nvidia    400
# AMD       180
# Name: Gpu brand, dtype: int64

# %%
df['Gpu brand'].value_counts().plot(kind='bar')
plt.xlabel('Gpu brand')
plt.ylabel('Frequency')
plt.title('Histogram of  Gpu brand')
# Out:
# Text(0.5, 1.0, 'Histogram of  Gpu brand')

# %%
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %%
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head(5)
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand
# 0  226.983005  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.211998  Intel Core i5    0  256     Intel
# 3  220.534624  Intel Core i7    0  512       AMD
# 4  226.983005  Intel Core i5    0  256     Intel

# %% [markdown]
# ### Dealing with OpSys feature

# %%
df['OpSys'].value_counts()
# Out:
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: OpSys, dtype: int64

# %%
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName  Ram  OpSys  Weight        Price  Touchscreen  Ips  \
# 0   Apple  Ultrabook    8  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook    8  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook    8  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook   16  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook    8  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0  226.983005  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.211998  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534624  Intel Core i7    0  512       AMD                 Mac
# 4  226.983005  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ### Dealing with Weight feature

# %%
df['Weight'].value_counts()
# Out:
# 2.20    126
# 2.10     58
# 2.00     45
# 2.40     44
# 2.30     41
#        ...
# 4.50      1
# 1.14      1
# 3.80      1
# 2.26      1
# 2.34      1
# Name: Weight, Length: 171, dtype: int64

# %%
sns.displot(df['Weight'])

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %% [markdown]
#  # 3. Feature Engineering

# %%
df.corr()['Price']
# Out:
# Ram            0.742905
# Weight         0.209867
# Price          1.000000
# Touchscreen    0.192917
# Ips            0.253320
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
sns.distplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.distplot(np.log(df['Price']))
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 0      Apple           Ultrabook    8    1.37            0    1  226.983005
# 1      Apple           Ultrabook    8    1.34            0    0  127.677940
# 2         HP            Notebook    8    1.86            0    0  141.211998
# 3      Apple           Ultrabook   16    1.83            0    1  220.534624
# 4      Apple           Ultrabook    8    1.37            0    1  226.983005
# ...      ...                 ...  ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80            1    1  157.350512
# 1299  Lenovo  2 in 1 Convertible   16    1.30            1    1  276.053530
# 1300  Lenovo            Notebook    2    1.50            0    0  111.935204
# 1301      HP            Notebook    6    2.19            0    0  100.454670
# 1302    Asus            Notebook    4    2.20            0    0  100.454670
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR

# %% [markdown]
# # 4. Model Selection

# %% [markdown]
# ## 4.1 Linear Regression

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8073277448418701
# MAE 0.21017827976428766

# %% [markdown]
# ## 4.2 KNN

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = KNeighborsRegressor(n_neighbors=3)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8009101720524295
# MAE 0.19413408395581944

# %% [markdown]
# ## 4.3 Decision Tree

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = DecisionTreeRegressor(max_depth=8)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8476821794593352
# MAE 0.1789785187043034

# %% [markdown]
# ## 4.4 SVM

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8083180902289917
# MAE 0.2023905942719158

# %% [markdown]
# ## 4.5 Random Forest

# %%
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse=False,drop='first'),[0,1,7,10,11])
],remainder='passthrough')

step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

pipe.fit(X_train,y_train)

y_pred = pipe.predict(X_test)

print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8873402378382488
# MAE 0.15860130110457718

# %% [markdown]
# # 5. Exporting Model

# %%
import pickle

pickle.dump(df,open('df1.pkl','wb'))
pickle.dump(pipe,open('pipe1.pkl','wb'))

# %%
df
# Out:
#      Company            TypeName  Ram  Weight        Price  Touchscreen  Ips  \
# 0      Apple           Ultrabook    8    1.37   71378.6832            0    1
# 1      Apple           Ultrabook    8    1.34   47895.5232            0    0
# 2         HP            Notebook    8    1.86   30636.0000            0    0
# 3      Apple           Ultrabook   16    1.83  135195.3360            0    1
# 4      Apple           Ultrabook    8    1.37   96095.8080            0    1
# ...      ...                 ...  ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible    4    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible   16    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook    2    1.50   12201.1200            0    0
# 1301      HP            Notebook    6    2.19   40705.9200            0    0
# 1302    Asus            Notebook    4    2.20   19660.3200            0    0
#
# ...

# %%
X_train
# Out:
#       Company            TypeName  Ram  Weight  Touchscreen  Ips         ppi  \
# 183   Toshiba            Notebook    8    2.00            0    0  100.454670
# 1141      MSI              Gaming    8    2.40            0    0  141.211998
# 1049     Asus             Netbook    4    1.20            0    0  135.094211
# 1020     Dell  2 in 1 Convertible    4    2.08            1    1  141.211998
# 878      Dell            Notebook    4    2.18            0    0  141.211998
# ...       ...                 ...  ...     ...          ...  ...         ...
# 466      Acer            Notebook    4    2.20            0    0  100.454670
# 299      Asus           Ultrabook   16    1.63            0    0  141.211998
# 493      Acer            Notebook    8    2.20            0    0  100.454670
# 527    Lenovo            Notebook    8    2.20            0    0  100.454670
# 1193    Apple           Ultrabook    8    0.92            0    1  226.415547
#
# ...

# %% [markdown]
# # 6. Observation
#  ### Random Forest Model gives the best R2 score
#
# ### R2 score 0.8873402378382488
#
# ### MAE 0.15860130110457718
